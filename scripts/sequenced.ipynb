# %%
from ragraph.io.esl import from_esl
graph = from_esl(["./esl"])

from utils import set_edge_weights, annotate_variable_type
set_edge_weights(graph)
annotate_variable_type(graph)

# %%
from ragraph.analysis import sequence
import ragraph.plot

from raesl.plot.view_funcs import multi_domain
import raesl.plot

nodes, edges = multi_domain(
    graph,
    depth=4
)

relations = [n for n in nodes if n.kind == "relation_spec"]
variables = [n for n in nodes if n.kind == "variable"]
components = [n for n in nodes if n.kind == "component"]


_, _, sequenced_functions = sequence.utils.branchsort(algo=sequence.scc_tearing, graph=graph, algo_args=dict(inf=1, dep=1, mu=3), inplace=True, nodes=relations+variables, edge_weights=graph.weights)

# Reload figure based on sequence.
# figure = raesl.plot.mdm(
#     graph,
#     depth=2,
# )

figure = ragraph.plot.mdm(
    leafs = components + sequenced_functions,
    edges = edges,
    node_kinds=["component", "relation_spec", "variable"],
    style= ragraph.plot.Style(
        piemap=dict(
            display="labels",
            mode= "relative"
        ),
    )
)

figure.write_image("../figures/mdm_sequenced.svg")
figure.show()

figure = ragraph.plot.mdm(
    leafs = components + sequenced_functions,
    edges = edges,
    node_kinds=["component", "relation_spec", "variable"],
    style= ragraph.plot.Style(
        piemap=dict(
            display="weights",
            mode= "relative",
            fields=["weight"]
        ),
    )
)

figure.write_image("../figures/mdm_sequenced_weighted.svg")
figure.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 40
#      37 figure.write_image("../figures/mdm_sequenced.svg")
#      38 figure.show()
# ---> 40 figure = ragraph.plot.mdm(
#      41     leafs = components + sequenced_functions,
#      42     edges = edges,
#      43     node_kinds=["component", "relation_spec", "variable"],
#      44     style= ragraph.plot.Style(
#      45         piemap=dict(
#      46             display="weights labels",
#      47             mode= "relative",
#      48             fields=["weight"]
#      49         ),
#      50     )
#      51 )
#      53 figure.write_image("../figures/mdm_sequenced_weighted.svg")
#      54 figure.show()
#
# File ~/Projects/4CM70-integrated-system-design-DSM/.venv/lib/python3.13/site-packages/ragraph/plot/__init__.py:134, in mdm(leafs, edges, style, sort, sort_args, node_kinds, show)
#     130     leafs = utils.get_axis_sequence(leafs, kinds=node_kinds, **sort_args)
#     132 grid = utils.get_mdm_grid(leafs=leafs, edges=edges, style=style)
# --> 134 fig = utils.get_subplots(grid, style=style)
#     136 return utils.process_fig(fig=fig, show=show, style=style)
#
# File ~/Projects/4CM70-integrated-system-design-DSM/.venv/lib/python3.13/site-packages/ragraph/plot/utils.py:36, in get_subplots(components, style)
#      30 components_t = list(zip(*components))  # Transpose helper matrix.
#      31 cols = len(components_t)
#      33 min_x_ranges = [
#      34     (
#      35         min(
# ---> 36             [comp.xaxis.range[0] for comp in col if comp and comp.xaxis.range],
#      37             default=0,
#      38         )
#      39         if any(col)
#      40         else 0
#      41     )
#      42     for col in components_t
#      43     if components_t
#      44 ]
#      46 max_x_ranges = [
#      47     (
#      48         max(
#    (...)     55     for col in components_t
#      56 ]
#      58 widths = [(x_max - x_min) * style.boxsize for (x_max, x_min) in zip(max_x_ranges, min_x_ranges)]
#
# File ~/Projects/4CM70-integrated-system-design-DSM/.venv/lib/python3.13/site-packages/ragraph/generic.py:77, in field.<locals>.getter(self)
#      75 def getter(self):
#      76     """Get a mapping value."""
# ---> 77     if key in self._data:
#      78         return self._data[key]
#      80     if key in self._defaults:
#
# AttributeError: 'Legend' object has no attribute '_data'
